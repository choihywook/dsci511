# %% [markdown]
# ## Module submission header
# ### Submission preparation instructions
# _Completion of this header is mandatory, subject to a 2-point deduction to the assignment._ Only add plain text in the designated areas, i.e., replacing the relevant 'NA's. You must fill out all group member Names and Drexel email addresses in the below markdown list, under header __Module submission group__. It is required to fill out descriptive notes pertaining to any tutoring support received in the completion of this submission under the __Additional submission comments__ section at the bottom of the header. If no tutoring support was received, leave NA in place. You may as well list other optional comments pertaining to the submission at bottom. _Any distruption of this header's formatting will make your group liable to the 2-point deduction._
#
# ### Module submission group
# - Group member 1
#     - Name: NA
#     - Email: NA
# - Group member 2
#     - Name: NA
#     - Email: NA
# - Group member 3
#     - Name: NA
#     - Email: NA
# - Group member 4
#     - Name: NA
#     - Email: NA
#
# ### Additional submission comments
# - Tutoring support received: NA
# - Other (other): NA

# %% [markdown]
# # Assignment Group 1

# %% [markdown]
# ## Module B _(23 points)_
#
# __B1.__ _(5 points)_ You will be using part of the [Goodbooks 10k dataset](https://github.com/zygmuntz/goodbooks-10k) for this module. Read the `data/goodreads-books.csv` file into a list. Create a dictionary for each book in the list that contains these fields: authors, original title, original publication year, average rating, and ratings count. (You should convert average rating and ratings count into `float` and `int` types.) Put all these metadata dictionaries into a list.

# %%
import csv
reader = csv.reader(open("data/goodreads-books.csv", "r"))
goodreadsBooks = list(reader)

# %%
bookMetadata = []
for book in goodreadsBooks[1:]:
    metadata = {
        "authors" : book[7],
        "title" : book[9],
        "publication year" : book[8],
        "average rating" : float(book[12]),
        "ratings count" : int(book[13])
    }
    bookMetadata.append(metadata)

# %% [markdown]
# __B2.__ _(4 points)_ Write a function to sort this list of book metadata in descending order of average rating. The function should take the list of metadata dictionaries as an input argument.

# %%
def sortMetadata(bookMetadata):
    return sorted(bookMetadata, key = lambda x: x["average rating"], reverse = True)

# %% [markdown]
# __B3.__ _(5 points)_ Update the function to take two arguments: the list, and an integer value for minimum ratings count. The function should now sort _and_ filter the list, returning a list of books sorted by average rating that have been rated by more than a specified number of users. You can use three different approaches: loops, comprehensions, and the built-in `filter()` function (look up documentation and examples).

# %%
def sortFilter(bookMetadata, minRatingCount):
    newMetadata = []
    for metadata in bookMetadata:
        if metadata["ratings count"] > minRatingCount:
            newMetadata.append(metadata)
    return sorted(newMetadata, key = lambda x: x["average rating"], reverse = True)

# %%
from pprint import pprint
pprint(sortFilter(bookMetadata, 1000000))
# Out:
# [{'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.61,
#   'publication year': '2007.0',
#   'ratings count': 1746574,
#   'title': 'Harry Potter and the Deathly Hallows'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.54,
#   'publication year': '2005.0',
#   'ratings count': 1678823,
#   'title': 'Harry Potter and the Half-Blood Prince'},
#  {'authors': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'average rating': 4.53,
#   'publication year': '1999.0',
#   'ratings count': 1832823,
#   'title': 'Harry Potter and the Prisoner of Azkaban'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.53,
#   'publication year': '2000.0',
#   'ratings count': 1753043,
#   'title': 'Harry Potter and the Goblet of Fire'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.46,
#   'publication year': '2003.0',
#   'ratings count': 1735368,
#   'title': 'Harry Potter and the Order of the Phoenix'},
#  {'authors': 'Kathryn Stockett',
#   'average rating': 4.45,
#   'publication year': '2009.0',
#   'ratings count': 1531753,
#   'title': 'The Help'},
#  {'authors': 'George R.R. Martin',
#   'average rating': 4.45,
#   'publication year': '1996.0',
#   'ratings count': 1319204,
#   'title': 'A Game of Thrones'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.44,
#   'publication year': '1997.0',
#   'ratings count': 4602479,
#   'title': "Harry Potter and the Philosopher's Stone"},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.37,
#   'publication year': '1998.0',
#   'ratings count': 1779331,
#   'title': 'Harry Potter and the Chamber of Secrets'},
#  {'authors': 'Markus Zusak',
#   'average rating': 4.36,
#   'publication year': '2005.0',
#   'ratings count': 1159741,
#   'title': 'The Book Thief'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.34,
#   'publication year': '2008.0',
#   'ratings count': 4780653,
#   'title': 'The Hunger Games'},
#  {'authors': 'J.R.R. Tolkien',
#   'average rating': 4.34,
#   'publication year': '1954.0',
#   'ratings count': 1766803,
#   'title': ' The Fellowship of the Ring'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.3,
#   'publication year': '2009.0',
#   'ratings count': 1831039,
#   'title': 'Catching Fire'},
#  {'authors': 'Shel Silverstein',
#   'average rating': 4.29,
#   'publication year': '1974.0',
#   'ratings count': 1016888,
#   'title': 'Where the Sidewalk Ends: The Poems and Drawings of Shel '
#            'Silverstein'},
#  {'authors': 'John Green',
#   'average rating': 4.26,
#   'publication year': '2012.0',
#   'ratings count': 2346404,
#   'title': 'The Fault in Our Stars'},
#  {'authors': 'Khaled Hosseini',
#   'average rating': 4.26,
#   'publication year': '2003.0',
#   'ratings count': 1813044,
#   'title': 'The Kite Runner '},
#  {'authors': 'Harper Lee',
#   'average rating': 4.25,
#   'publication year': '1960.0',
#   'ratings count': 3198671,
#   'title': 'To Kill a Mockingbird'},
#  {'authors': 'J.R.R. Tolkien',
#   'average rating': 4.25,
#   'publication year': '1937.0',
#   'ratings count': 2071616,
#   'title': 'The Hobbit or There and Back Again'},
#  {'authors': 'Jane Austen',
#   'average rating': 4.24,
#   'publication year': '1813.0',
#   'ratings count': 2035490,
#   'title': 'Pride and Prejudice'},
#  {'authors': 'Veronica Roth',
#   'average rating': 4.24,
#   'publication year': '2011.0',
#   'ratings count': 1903563,
#   'title': 'Divergent'},
#  {'authors': 'Rick Riordan',
#   'average rating': 4.23,
#   'publication year': '2005.0',
#   'ratings count': 1366265,
#   'title': 'The Lightning Thief'},
#  {'authors': 'C.S. Lewis',
#   'average rating': 4.19,
#   'publication year': '1950.0',
#   'ratings count': 1531800,
#   'title': 'The Lion, the Witch and the Wardrobe'},
#  {'authors': 'E.B. White, Garth Williams, Rosemary Wells',
#   'average rating': 4.15,
#   'publication year': '1952.0',
#   'ratings count': 1064521,
#   'title': "Charlotte's Web"},
#  {'authors': 'George Orwell, Erich Fromm, Celâl Üster',
#   'average rating': 4.14,
#   'publication year': '1949.0',
#   'ratings count': 1956832,
#   'title': 'Nineteen Eighty-Four'},
#  {'authors': 'Lois Lowry',
#   'average rating': 4.12,
#   'publication year': '1993.0',
#   'ratings count': 1296825,
#   'title': 'The Giver'},
#  {'authors': 'Cassandra Clare',
#   'average rating': 4.12,
#   'publication year': '2007.0',
#   'ratings count': 1154031,
#   'title': 'City of Bones'},
#  {'authors': 'Stieg Larsson, Reg Keeland',
#   'average rating': 4.11,
#   'publication year': '2005.0',
#   'ratings count': 1808403,
#   'title': 'Män som hatar kvinnor'},
#  {'authors': 'Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-Doubleday',
#   'average rating': 4.1,
#   'publication year': '1947.0',
#   'ratings count': 1972666,
#   'title': 'Het Achterhuis: Dagboekbrieven 14 juni 1942 - 1 augustus 1944'},
#  {'authors': 'Charlotte Brontë, Michael Mason',
#   'average rating': 4.1,
#   'publication year': '1847.0',
#   'ratings count': 1198557,
#   'title': 'Jane Eyre'},
#  {'authors': 'Arthur Golden',
#   'average rating': 4.08,
#   'publication year': '1997.0',
#   'ratings count': 1300209,
#   'title': 'Memoirs of a Geisha'},
#  {'authors': 'Sara Gruen',
#   'average rating': 4.07,
#   'publication year': '2006.0',
#   'ratings count': 1068146,
#   'title': 'Water for Elephants'},
#  {'authors': 'Nicholas Sparks',
#   'average rating': 4.06,
#   'publication year': '1996.0',
#   'ratings count': 1053403,
#   'title': 'The Notebook'},
#  {'authors': 'Louisa May Alcott',
#   'average rating': 4.04,
#   'publication year': '1868.0',
#   'ratings count': 1257121,
#   'title': 'Little Women'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.03,
#   'publication year': '2010.0',
#   'ratings count': 1719760,
#   'title': 'Mockingjay'},
#  {'authors': 'Aldous Huxley',
#   'average rating': 3.97,
#   'publication year': '1932.0',
#   'ratings count': 1022601,
#   'title': 'Brave New World'},
#  {'authors': 'F. Scott Fitzgerald',
#   'average rating': 3.89,
#   'publication year': '1925.0',
#   'ratings count': 2683664,
#   'title': 'The Great Gatsby'},
#  {'authors': 'Yann Martel',
#   'average rating': 3.88,
#   'publication year': '2001.0',
#   'ratings count': 1003228,
#   'title': 'Life of Pi'},
#  {'authors': 'Paula Hawkins',
#   'average rating': 3.88,
#   'publication year': '2015.0',
#   'ratings count': 1008778,
#   'title': 'The Girl on the Train'},
#  {'authors': 'George Orwell',
#   'average rating': 3.87,
#   'publication year': '1945.0',
#   'ratings count': 1881700,
#   'title': 'Animal Farm: A Fairy Story'},
#  {'authors': 'Christopher Paolini',
#   'average rating': 3.86,
#   'publication year': '2002.0',
#   'ratings count': 1104021,
#   'title': 'Eragon'},
#  {'authors': 'Dan Brown',
#   'average rating': 3.85,
#   'publication year': '2000.0',
#   'ratings count': 2001311,
#   'title': 'Angels & Demons '},
#  {'authors': 'John Steinbeck',
#   'average rating': 3.84,
#   'publication year': '1937.0',
#   'ratings count': 1467496,
#   'title': 'Of Mice and Men '},
#  {'authors': 'Paulo Coelho, Alan R. Clarke',
#   'average rating': 3.82,
#   'publication year': '1988.0',
#   'ratings count': 1299566,
#   'title': 'O Alquimista'},
#  {'authors': 'J.D. Salinger',
#   'average rating': 3.79,
#   'publication year': '1951.0',
#   'ratings count': 2044241,
#   'title': 'The Catcher in the Rye'},
#  {'authors': 'Dan Brown',
#   'average rating': 3.79,
#   'publication year': '2003.0',
#   'ratings count': 1447148,
#   'title': 'The Da Vinci Code'},
#  {'authors': 'Alice Sebold',
#   'average rating': 3.77,
#   'publication year': '2002.0',
#   'ratings count': 1605173,
#   'title': 'The Lovely Bones'},
#  {'authors': 'William Shakespeare, Robert           Jackson',
#   'average rating': 3.73,
#   'publication year': '1595.0',
#   'ratings count': 1628519,
#   'title': 'An Excellent conceited Tragedie of Romeo and Juliet'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.7,
#   'publication year': '2008.0',
#   'ratings count': 1070245,
#   'title': 'Breaking Dawn'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.69,
#   'publication year': '2007.0',
#   'ratings count': 1134511,
#   'title': 'Eclipse'},
#  {'authors': 'E.L. James',
#   'average rating': 3.67,
#   'publication year': '2011.0',
#   'ratings count': 1338493,
#   'title': 'Fifty Shades of Grey'},
#  {'authors': 'William Golding',
#   'average rating': 3.64,
#   'publication year': '1954.0',
#   'ratings count': 1605019,
#   'title': 'Lord of the Flies '},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.57,
#   'publication year': '2005.0',
#   'ratings count': 3866839,
#   'title': 'Twilight'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.52,
#   'publication year': '2006.0',
#   'ratings count': 1149630,
#   'title': 'New Moon (Twilight, #2)'},
#  {'authors': 'Elizabeth Gilbert',
#   'average rating': 3.51,
#   'publication year': '2006.0',
#   'ratings count': 1181647,
#   'title': "Eat, pray, love: one woman's search for everything across Italy, "
#            'India and Indonesia'}]

# %% [markdown]
# __B4:__ _(7 points)_ Now use the other two approaches to create different versions of the function. See if you can condense your code into a single line for some of the approaches!

# %%
def sortFilter(bookMetadata, minRatingCount):
    return sorted([metadata for metadata in bookMetadata if metadata["ratings count"] > minRatingCount], key = lambda x: x["average rating"], reverse = True)

# %%
pprint(sortFilter(bookMetadata, 1000000))
# Out:
# [{'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.61,
#   'publication year': '2007.0',
#   'ratings count': 1746574,
#   'title': 'Harry Potter and the Deathly Hallows'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.54,
#   'publication year': '2005.0',
#   'ratings count': 1678823,
#   'title': 'Harry Potter and the Half-Blood Prince'},
#  {'authors': 'J.K. Rowling, Mary GrandPré, Rufus Beck',
#   'average rating': 4.53,
#   'publication year': '1999.0',
#   'ratings count': 1832823,
#   'title': 'Harry Potter and the Prisoner of Azkaban'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.53,
#   'publication year': '2000.0',
#   'ratings count': 1753043,
#   'title': 'Harry Potter and the Goblet of Fire'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.46,
#   'publication year': '2003.0',
#   'ratings count': 1735368,
#   'title': 'Harry Potter and the Order of the Phoenix'},
#  {'authors': 'Kathryn Stockett',
#   'average rating': 4.45,
#   'publication year': '2009.0',
#   'ratings count': 1531753,
#   'title': 'The Help'},
#  {'authors': 'George R.R. Martin',
#   'average rating': 4.45,
#   'publication year': '1996.0',
#   'ratings count': 1319204,
#   'title': 'A Game of Thrones'},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.44,
#   'publication year': '1997.0',
#   'ratings count': 4602479,
#   'title': "Harry Potter and the Philosopher's Stone"},
#  {'authors': 'J.K. Rowling, Mary GrandPré',
#   'average rating': 4.37,
#   'publication year': '1998.0',
#   'ratings count': 1779331,
#   'title': 'Harry Potter and the Chamber of Secrets'},
#  {'authors': 'Markus Zusak',
#   'average rating': 4.36,
#   'publication year': '2005.0',
#   'ratings count': 1159741,
#   'title': 'The Book Thief'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.34,
#   'publication year': '2008.0',
#   'ratings count': 4780653,
#   'title': 'The Hunger Games'},
#  {'authors': 'J.R.R. Tolkien',
#   'average rating': 4.34,
#   'publication year': '1954.0',
#   'ratings count': 1766803,
#   'title': ' The Fellowship of the Ring'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.3,
#   'publication year': '2009.0',
#   'ratings count': 1831039,
#   'title': 'Catching Fire'},
#  {'authors': 'Shel Silverstein',
#   'average rating': 4.29,
#   'publication year': '1974.0',
#   'ratings count': 1016888,
#   'title': 'Where the Sidewalk Ends: The Poems and Drawings of Shel '
#            'Silverstein'},
#  {'authors': 'John Green',
#   'average rating': 4.26,
#   'publication year': '2012.0',
#   'ratings count': 2346404,
#   'title': 'The Fault in Our Stars'},
#  {'authors': 'Khaled Hosseini',
#   'average rating': 4.26,
#   'publication year': '2003.0',
#   'ratings count': 1813044,
#   'title': 'The Kite Runner '},
#  {'authors': 'Harper Lee',
#   'average rating': 4.25,
#   'publication year': '1960.0',
#   'ratings count': 3198671,
#   'title': 'To Kill a Mockingbird'},
#  {'authors': 'J.R.R. Tolkien',
#   'average rating': 4.25,
#   'publication year': '1937.0',
#   'ratings count': 2071616,
#   'title': 'The Hobbit or There and Back Again'},
#  {'authors': 'Jane Austen',
#   'average rating': 4.24,
#   'publication year': '1813.0',
#   'ratings count': 2035490,
#   'title': 'Pride and Prejudice'},
#  {'authors': 'Veronica Roth',
#   'average rating': 4.24,
#   'publication year': '2011.0',
#   'ratings count': 1903563,
#   'title': 'Divergent'},
#  {'authors': 'Rick Riordan',
#   'average rating': 4.23,
#   'publication year': '2005.0',
#   'ratings count': 1366265,
#   'title': 'The Lightning Thief'},
#  {'authors': 'C.S. Lewis',
#   'average rating': 4.19,
#   'publication year': '1950.0',
#   'ratings count': 1531800,
#   'title': 'The Lion, the Witch and the Wardrobe'},
#  {'authors': 'E.B. White, Garth Williams, Rosemary Wells',
#   'average rating': 4.15,
#   'publication year': '1952.0',
#   'ratings count': 1064521,
#   'title': "Charlotte's Web"},
#  {'authors': 'George Orwell, Erich Fromm, Celâl Üster',
#   'average rating': 4.14,
#   'publication year': '1949.0',
#   'ratings count': 1956832,
#   'title': 'Nineteen Eighty-Four'},
#  {'authors': 'Lois Lowry',
#   'average rating': 4.12,
#   'publication year': '1993.0',
#   'ratings count': 1296825,
#   'title': 'The Giver'},
#  {'authors': 'Cassandra Clare',
#   'average rating': 4.12,
#   'publication year': '2007.0',
#   'ratings count': 1154031,
#   'title': 'City of Bones'},
#  {'authors': 'Stieg Larsson, Reg Keeland',
#   'average rating': 4.11,
#   'publication year': '2005.0',
#   'ratings count': 1808403,
#   'title': 'Män som hatar kvinnor'},
#  {'authors': 'Anne Frank, Eleanor Roosevelt, B.M. Mooyaart-Doubleday',
#   'average rating': 4.1,
#   'publication year': '1947.0',
#   'ratings count': 1972666,
#   'title': 'Het Achterhuis: Dagboekbrieven 14 juni 1942 - 1 augustus 1944'},
#  {'authors': 'Charlotte Brontë, Michael Mason',
#   'average rating': 4.1,
#   'publication year': '1847.0',
#   'ratings count': 1198557,
#   'title': 'Jane Eyre'},
#  {'authors': 'Arthur Golden',
#   'average rating': 4.08,
#   'publication year': '1997.0',
#   'ratings count': 1300209,
#   'title': 'Memoirs of a Geisha'},
#  {'authors': 'Sara Gruen',
#   'average rating': 4.07,
#   'publication year': '2006.0',
#   'ratings count': 1068146,
#   'title': 'Water for Elephants'},
#  {'authors': 'Nicholas Sparks',
#   'average rating': 4.06,
#   'publication year': '1996.0',
#   'ratings count': 1053403,
#   'title': 'The Notebook'},
#  {'authors': 'Louisa May Alcott',
#   'average rating': 4.04,
#   'publication year': '1868.0',
#   'ratings count': 1257121,
#   'title': 'Little Women'},
#  {'authors': 'Suzanne Collins',
#   'average rating': 4.03,
#   'publication year': '2010.0',
#   'ratings count': 1719760,
#   'title': 'Mockingjay'},
#  {'authors': 'Aldous Huxley',
#   'average rating': 3.97,
#   'publication year': '1932.0',
#   'ratings count': 1022601,
#   'title': 'Brave New World'},
#  {'authors': 'F. Scott Fitzgerald',
#   'average rating': 3.89,
#   'publication year': '1925.0',
#   'ratings count': 2683664,
#   'title': 'The Great Gatsby'},
#  {'authors': 'Yann Martel',
#   'average rating': 3.88,
#   'publication year': '2001.0',
#   'ratings count': 1003228,
#   'title': 'Life of Pi'},
#  {'authors': 'Paula Hawkins',
#   'average rating': 3.88,
#   'publication year': '2015.0',
#   'ratings count': 1008778,
#   'title': 'The Girl on the Train'},
#  {'authors': 'George Orwell',
#   'average rating': 3.87,
#   'publication year': '1945.0',
#   'ratings count': 1881700,
#   'title': 'Animal Farm: A Fairy Story'},
#  {'authors': 'Christopher Paolini',
#   'average rating': 3.86,
#   'publication year': '2002.0',
#   'ratings count': 1104021,
#   'title': 'Eragon'},
#  {'authors': 'Dan Brown',
#   'average rating': 3.85,
#   'publication year': '2000.0',
#   'ratings count': 2001311,
#   'title': 'Angels & Demons '},
#  {'authors': 'John Steinbeck',
#   'average rating': 3.84,
#   'publication year': '1937.0',
#   'ratings count': 1467496,
#   'title': 'Of Mice and Men '},
#  {'authors': 'Paulo Coelho, Alan R. Clarke',
#   'average rating': 3.82,
#   'publication year': '1988.0',
#   'ratings count': 1299566,
#   'title': 'O Alquimista'},
#  {'authors': 'J.D. Salinger',
#   'average rating': 3.79,
#   'publication year': '1951.0',
#   'ratings count': 2044241,
#   'title': 'The Catcher in the Rye'},
#  {'authors': 'Dan Brown',
#   'average rating': 3.79,
#   'publication year': '2003.0',
#   'ratings count': 1447148,
#   'title': 'The Da Vinci Code'},
#  {'authors': 'Alice Sebold',
#   'average rating': 3.77,
#   'publication year': '2002.0',
#   'ratings count': 1605173,
#   'title': 'The Lovely Bones'},
#  {'authors': 'William Shakespeare, Robert           Jackson',
#   'average rating': 3.73,
#   'publication year': '1595.0',
#   'ratings count': 1628519,
#   'title': 'An Excellent conceited Tragedie of Romeo and Juliet'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.7,
#   'publication year': '2008.0',
#   'ratings count': 1070245,
#   'title': 'Breaking Dawn'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.69,
#   'publication year': '2007.0',
#   'ratings count': 1134511,
#   'title': 'Eclipse'},
#  {'authors': 'E.L. James',
#   'average rating': 3.67,
#   'publication year': '2011.0',
#   'ratings count': 1338493,
#   'title': 'Fifty Shades of Grey'},
#  {'authors': 'William Golding',
#   'average rating': 3.64,
#   'publication year': '1954.0',
#   'ratings count': 1605019,
#   'title': 'Lord of the Flies '},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.57,
#   'publication year': '2005.0',
#   'ratings count': 3866839,
#   'title': 'Twilight'},
#  {'authors': 'Stephenie Meyer',
#   'average rating': 3.52,
#   'publication year': '2006.0',
#   'ratings count': 1149630,
#   'title': 'New Moon (Twilight, #2)'},
#  {'authors': 'Elizabeth Gilbert',
#   'average rating': 3.51,
#   'publication year': '2006.0',
#   'ratings count': 1181647,
#   'title': "Eat, pray, love: one woman's search for everything across Italy, "
#            'India and Indonesia'}]

# %% [markdown]
# __B5.__ _(2 points)_ Why is using a function for this task prudent? What do you think is an acceptable minimum ratings count? Answer these questiions in the response box below.

# %% [markdown]
# Response.
